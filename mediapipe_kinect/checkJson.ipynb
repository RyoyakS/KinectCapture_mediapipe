# %%
import pandas as pd

# %%
df = pd.read_json("./json/Arlequin_above_labeled.json")

# %%
df
# Out:
#       Frame#   Time (s)                                          landmarks  \
# 0          0   0.000000  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 1          1   0.016667  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 2          2   0.033333  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 3          3   0.050000  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 4          4   0.066667  [{'hand': 'left hand', 'landmarks': [{'landmar...
# ...      ...        ...                                                ...
# 2931    2931  48.850000  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 2932    2932  48.866667  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 2933    2933  48.883333  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 2934    2934  48.900000  [{'hand': 'left hand', 'landmarks': [{'landmar...
# 2935    2935  48.916667  [{'hand': 'left hand', 'landmarks': [{'landmar...
#
#       Valence  Arousal
# 0           0        0
# ...
